# %%
# !pip install bing_image_downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
mkdir images

# %%
from bing_image_downloader import downloader
downloader.download('apple fruit', limit = 100, output_dir = 'images')
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
# [!!]Indexing page: 35
#
# [%] Indexed 9 Images on Page 35.
#
# ...
#
#
#
# [!!]Indexing page: 36
#
# [%] Indexed 9 Images on Page 36.
#
# ...
#
#
#
# [!!]Indexing page: 37
#
# [%] Indexed 9 Images on Page 37.
#
# ...
#
#
#
# [!!]Indexing page: 38
#
# [%] Indexed 9 Images on Page 38.
#
# ...
#
#
#
# [!!]Indexing page: 39
#
# [%] Indexed 9 Images on Page 39.
#
# ...
#
#
#
# [!!]Indexing page: 40
#
# [%] Indexed 9 Images on Page 40.
#
# ...
#
#
#
# [!!]Indexing page: 41
#
# [%] Indexed 9 Images on Page 41.
#
# ...
#
#
#
# [!!]Indexing page: 42
#
# [%] Indexed 9 Images on Page 42.
#
# ...
#
#
#
# [!!]Indexing page: 43
#
# [%] Indexed 9 Images on Page 43.
#
# ...
#
#
#
# [!!]Indexing page: 44
#
# [%] Indexed 9 Images on Page 44.
#
# ...
#
#
#
# [!!]Indexing page: 45
#
# [%] Indexed 9 Images on Page 45.
#
# ...
#
#
#
# [!!]Indexing page: 46
#
# [%] Indexed 9 Images on Page 46.
#
# ...
#
#
#
# [!!]Indexing page: 47
#
# [%] Indexed 9 Images on Page 47.
#
# ...
#
#
#
# [!!]Indexing page: 48
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download('mango', limit = 100, output_dir = 'images')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# ...
#
#
#
# [!!]Indexing page: 98
#
# [%] Indexed 9 Images on Page 98.
#
# ...
#
#
#
# [!!]Indexing page: 99
#
# [%] Indexed 9 Images on Page 99.
#
# ...
#
#
#
# [!!]Indexing page: 100
#
# [%] Indexed 9 Images on Page 100.
#
# ...
#
#
#
# [!!]Indexing page: 101
#
# [%] Indexed 10 Images on Page 101.
#
# ...
#
#
#
# [!!]Indexing page: 102
#
# [%] Indexed 9 Images on Page 102.
#
# ...
#
#
#
# [!!]Indexing page: 103
#
# [%] Indexed 10 Images on Page 103.
#
# ...
#
#
#
# [!!]Indexing page: 104
#
# [%] Indexed 9 Images on Page 104.
#
# ...
#
#
#
# [!!]Indexing page: 105
#
# [%] Indexed 9 Images on Page 105.
#
# ...
#
#
#
# [!!]Indexing page: 106
#
# [%] Indexed 9 Images on Page 106.
#
# ...
#
#
#
# [!!]Indexing page: 107
#
# [%] Indexed 10 Images on Page 107.
#
# ...
#
#
#
# [!!]Indexing page: 108
#
# [%] Indexed 9 Images on Page 108.
#
# ...
#
#
#
# [!!]Indexing page: 109
#
# [%] Indexed 9 Images on Page 109.
#
# ...
#
# ...

# %%
import tensorflow as tf

# %%
daily_sales_numbers = [21, 22, -108, 31, -1, 32, 34,31]

tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)
tf_dataset
# Out:
# <TensorSliceDataset element_spec=TensorSpec(shape=(), dtype=tf.int32, name=None)>

# %%
for sales in tf_dataset:
    print(sales.numpy())
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %%
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# -108
# 31
# -1
# 32
# 34
# 31

# %%
for sales in tf_dataset.take(3):
    print(sales.numpy())
# Out:
# 21
# 22
# -108

# %%
tf_dataset = tf_dataset.filter(lambda x: x>0)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# 21
# 22
# 31
# 32
# 34
# 31

# %%
tf_dataset = tf_dataset.map(lambda x: x * 50)
for sales in tf_dataset.as_numpy_iterator():
  print(sales)
# Out:
# 1050
# 1100
# 1550
# 1600
# 1700
# 1550

# %%
tf_dataset = tf_dataset.shuffle(3)
for sales in tf_dataset.as_numpy_iterator():
  print(sales)
# Out:
# 1050
# 1100
# 1550
# 1550
# 1700
# 1600

# %%
for sales_batch in tf_dataset.batch(3):
    print(sales_batch.numpy())
# Out:
# [1050 1550 1550]
# [1100 1600 1700]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)

tf_dataset = tf_dataset.filter(lambda x: x>0).map(lambda y: y*50).shuffle(3).batch(2)
for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# [1550 1600]
# [1700 1550]
# [1100 1050]

# %%
images_ds = tf.data.Dataset.list_files('images/*/*', shuffle = False)
for file in images_ds.take(5):
    print(file.numpy())
# Out:
# b'images/apple fruit/Image_1.jpg'
# b'images/apple fruit/Image_10.jpg'
# b'images/apple fruit/Image_100.jpg'
# b'images/apple fruit/Image_11.jpg'
# b'images/apple fruit/Image_12.png'

# %%
images_ds = images_ds.shuffle(200)
for file in images_ds.take(4):
    print(file.numpy())
# Out:
# b'images/apple fruit/Image_82.jpg'
# b'images/mango/Image_4.jpg'
# b'images/mango/Image_91.jpg'
# b'images/mango/Image_66.jpg'

# %%
image_count = len(images_ds)
print(image_count)
# Out:
# 200

# %%
class_names = ["apple fruit", "mango"]

# %%
train_size = int(image_count*0.8)
train_ds = images_ds.take(train_size)
test_ds = images_ds.skip(train_size)

# %%
print(len(train_ds))
print(len(test_ds))
# Out:
# 160
# 40

# %%
def process_image(file_path):
  label = get_label(file_path)
  img = tf.io.read_file(file_path)
  img = tf.image.decode_jpeg(img)
  img = tf.image.resize(img, [128,128])
  return img, label

# %%
def get_label(file_path):
    import os
    return tf.strings.split(file_path, os.path.sep)[1]

# %%
get_label('images/mango/Image_60.jpg')
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'mango'>

# %%
get_label("images/mango/Image_77.jpg")
# Out:
# <tf.Tensor: shape=(), dtype=string, numpy=b'mango'>

# %%
process_image('images/apple fruit/Image_100.jpg')
# Out:
# (<tf.Tensor: shape=(128, 128, 3), dtype=float32, numpy=
#  array([[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
# ...

# %%
p = 'images/mango/Image_90.jpg'
p.split('/')[1]
# Out:
# 'mango'

# %%
train_ds = train_ds.map(process_image)

for img, label in train_ds.take(1):
  print('Img***:',img)
  print('Label***:',label)
# Out:
# Img***: tf.Tensor(
# [[[  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   ...
#   [ 14.        14.        14.      ]
#   [ 14.        14.        14.      ]
#   [ 14.        14.        14.      ]]
#
#  [[  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   ...
#   [ 14.        14.        14.      ]
#   [ 14.        14.        14.      ]
#   [ 14.        14.        14.      ]]
#
#  [[  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   [  9.         9.         9.      ]
#   ...
#   [ 13.        13.        13.      ]
#   [ 13.        13.        13.      ]
#   [ 13.        13.        13.      ]]
#
#  ...
#
#  [[ 79.25659   37.31909   23.358154]
#   [ 77.21118   31.25      14.8125  ]
#   [ 72.08179   33.71289   12.533203]
#   ...
#   [151.91357   89.851074  38.723877]
#   [143.74658   88.61377   40.614502]
# ...

# %%
def scale(image, label):
    return image/255, label

# %%
train_ds = train_ds.map(scale)

# %%
for image, label in train_ds.take(5):
    print("****Image: ",image.numpy()[0][0])
    print("****Label: ",label.numpy())
# Out:
# ****Image:  [74.74609  17.746094 34.746094]
# ****Label:  b'mango'
# ****Image:  [225.6347 218.6347 225.6347]
# ****Label:  b'apple fruit'
# ****Image:  [120.78906 103.63867  91.91211]
# ****Label:  b'mango'
# ****Image:  [255. 255. 255.]
# ****Label:  b'mango'
# ****Image:  [20.992188  48.089844   5.1171875]
# ****Label:  b'apple fruit'
